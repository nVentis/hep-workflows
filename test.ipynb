# %%
import uproot

# %%
import uproot
def edm4hep_event_counter(file:str):
    try:
        with uproot.open(file) as rf:
            print(rf['events'].num_entries)
            return 1
    except Exception as e:
        print(e)
        return False

# %%
FILE = '/data/dust/group/ilc/ild/miniDST/edm4hep_minidst_devel/mc-2020/2f_hadronic_eL_pR/rv02-02.sv02-02.mILD_l5_o1_v02.E250-SetA.I500010.P2f_z_h.eL.pR.n009.d_dstm_15162_47-miniDST.edm4hep.root'

# %%
import uproot
f = uproot.open(FILE)
f['events'].num_entries

# %%
with uproot.open(FILE) as rf:
    print(rf['events'].num_entries)
# Out:
# 15200

# %%
# Out:
# 15200

# %%
print(f["events"].num_entries)
